# %% [markdown]
# <a href="https://colab.research.google.com/github/eeeewyz/Audio-course/blob/main/10_ASR_WER_CER_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
reference = "the cat sat on the mat"
prediction = "the cat sit on the"
# !pip install --upgrade evaluate jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 55.9 MB/s eta 0:00:00
# ...

# %%
#第一类：WER
#load the MER metrics
from evaluate import load

wer_metric = load("wer")

# %%
#调用：.compute
wer = wer_metric.compute(references=[reference], predictions=[prediction])

print(wer)
# Out:
# 0.3333333333333333

# %%
#第二类：CER
cer_metric = load("cer")
cer = cer_metric.compute(references=[reference], predictions=[prediction])
cer
# Out:
# 0.22727272727272727

# %%
#用一个whisper自带的normalize工具
from transformers.models.whisper.english_normalizer import BasicTextNormalizer
normalizer = BasicTextNormalizer()

# %%
prediction = " He tells us that at this festive season of the year, with Christmas and roast beef looming before us, similarly is drawn from eating and its results occur most readily to the mind."
#把prediction进行normalization
nomalized_prediction=normalizer(prediction)
nomalized_prediction
# Out:
# ' he tells us that at this festive season of the year with christmas and roast beef looming before us similarly is drawn from eating and its results occur most readily to the mind '

# %%
reference = "HE TELLS US THAT AT THIS FESTIVE SEASON OF THE YEAR WITH CHRISTMAS AND ROAST BEEF LOOMING BEFORE US SIMILES DRAWN FROM EATING AND ITS RESULTS OCCUR MOST READILY TO THE MIND"
#把reference进行noemalization
normalized_referece = normalizer(reference)

# %%
wer1 = wer_metric.compute(references=[normalized_referece], predictions=[nomalized_prediction])

# %%
wer1
# Out:
# 0.0625
